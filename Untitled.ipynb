# %%
import numpy as np

import seaborn as sns
import yaml
import os
import matplotlib.pyplot as plt
import pandas as pd
import unicodedata

def repl(text):
	return unicodedata.normalize('NFD', text).encode('ascii', 'ignore').decode('UTF-8').replace(",","_")

# %%
with open("_data/all.yaml") as f:
		alldata = yaml.safe_load(f)

# %%
with open("_data/page.yaml") as f:
		dic = yaml.safe_load(f)

# %%
labels = 'muž', 'žena' 
sizes = [dic["man"],dic["woman"]]
explode = (0, 0.1, )  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.grid(True)
plt.tight_layout()

plt.savefig("stats/gender.jpg")

# %%
field = [ e["field"] for e in alldata]
hindex = [ e["hindex"] for e in alldata]
sex = [ e["sex"] for e in alldata]
affiliation = [ e["affiliation"] for e in alldata]
country = [ e["country"] for e in alldata]

df = pd.DataFrame(data={"field":field,"hindex":hindex,
                        "affiliation":affiliation,
                        "country":country,
                        "sex":sex})

# %%
sns.set_theme(style="whitegrid", palette="muted")

# Draw a categorical scatterplot to show each observation
ax = sns.swarmplot(data=df, x="hindex", y="sex")# "species"
ax.set(ylabel="")
# Out:
# /home/taki/work/jointProjects/MARL/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 16.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# [Text(0, 0.5, '')]

# %%
from matplotlib.pyplot import figure

figure(figsize=(8, 20), dpi=80)

sns.set_theme(style="whitegrid", palette="muted")

# Draw a categorical scatterplot to show each observation
ax = sns.swarmplot(data=df, x="hindex", y="field")# "species"
ax.set(ylabel="")
# Out:
# /home/taki/work/jointProjects/MARL/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 20.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/taki/work/jointProjects/MARL/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 14.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/taki/work/jointProjects/MARL/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/taki/work/jointProjects/MARL/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 16.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/taki/work/jointProjects/MARL/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/taki/work/jointProjects/MARL/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 25.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# [Text(0, 0.5, '')]

# %%
sns.displot(data=df, x='hindex', kind='hist', hue="sex")

# %%
plt.hist(dic["hindex"],40)
plt.grid(True)

plt.tight_layout()
plt.savefig("stats/hindex.jpg")

# %%
ax = sns.displot(data=df, x='country', kind='hist', hue="sex")
plt.xticks(rotation=90);plt.xlabel("")
# Out:
# Text(0.5, 6.4599999999999795, '')

# %%
fig = plt.figure(figsize=(20, 5), dpi=100)
ax = fig.add_axes([0,0,1,1])

d = dic["affiliation"]
d = sorted([(k,d[k]) for k in d],  key = lambda e: (-e[1],repl(e[0])))


langs = [e[0] for e in d]
students = [e[1] for e in d]
ax.bar(langs,students)
plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 45-degrees
plt.grid(True)
plt.tight_layout()


plt.savefig("stats/affiliation.jpg", bbox_inches = 'tight')
# Out:
# <ipython-input-11-617845d9616f>:13: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
fig = plt.figure(figsize=(20, 5), dpi=100)
ax = fig.add_axes([0,0,1,1])

d = dic["countries"]
d = sorted([(k,d[k]) for k in d],  key = lambda e: (-e[1],repl(e[0])))


langs = [e[0] for e in d]
students = [e[1] for e in d]
ax.bar(langs,students)
plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 45-degrees
plt.grid(True)
plt.tight_layout()

plt.savefig("stats/countries.jpg", bbox_inches = 'tight')
# Out:
# <ipython-input-12-22bb35b0d1be>:13: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
dic.keys()
# Out:
# dict_keys(['affiliation', 'countries', 'hindex', 'man', 'woman'])
