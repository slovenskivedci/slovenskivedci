# %%
import numpy as np


import yaml
import os
import matplotlib.pyplot as plt

# %%
with open("_data/page.yaml") as f:
		dic = yaml.safe_load(f)

# %%
plt.hist(dic["hindex"],40)
plt.grid(True)
plt.savefig("stats/hindex.jpg")

# %%
dic
# Out:
# {'affiliation': {'Aalborg Universitet': 1,
#   'Amazon': 1,
#   'Apple': 1,
#   'Brookhaven National Laboratory': 1,
#   'CSIRO': 1,
#   'Central European University': 1,
#   'Curtin University': 1,
#   'Delft University of Technology': 2,
#   'ETH Zürich': 2,
#   'Európska komisia': 1,
#   'Florida State University': 1,
#   'Georga Mason University': 1,
#   'Google': 1,
#   'Hanover Medical University': 1,
#   'IST Austria': 1,
#   'Indiana University Bloomington': 1,
#   'Institute of Tropical Medicine Antwerp': 1,
#   'Joint Institute for Nuclear Research': 1,
#   'Karlsruhe Institute of Technology': 1,
#   'King Abdullah University of Science and Technology (KAUST)': 2,
#   'Krembil Research Institute': 1,
#   'Masarykova univerzita': 1,
#   'McMaster University': 1,
#   'Medical University of Vienna': 3,
#   'Microsoft Research': 1,
#   'Mohamed Bin Zayed University of Artificial Intelligence (MBZUAI)': 1,
#   'Monash University': 1,
#   'Moorfields Eye Hospital': 1,
#   'Murdoch University': 1,
#   'NGM Biopharmaceuticals': 1,
#   'National Institute of Allergy and Infectious Diseases': 1,
#   'National Research Council': 1,
#   'New York University': 1,
#   'Oregon State University': 1,
#   'Oxford University': 1,
#   'Qatar University': 2,
#   'RWTH Aachen': 1,
#   'Research and Development Services': 1,
#   'Simon Fraser University': 2,
#   'Slovenská akadémia vied': 31,
#   'Slovenská poľnohospodárska univerzita': 3,
#   'Slovenská technická univerzita': 7,
#   'Slovenská zdravotnícka univerzita': 1,
#   'Sloveská akadémia vied': 2,
#   'Stanford University': 1,
#   'Technická univerzita v Košiciach': 4,
#   'Technická univerzita vo Zvolene': 2,
#   'The University of Melbourne': 1,
#   'Trinity College Dublin': 1,
#   'Trnavská univerzita': 1,
#   'University Medical Center Utrecht': 1,
#   'University Oxford': 1,
#   'University of Adelaide': 2,
#   'University of Arizona': 1,
#   'University of Birmingham': 1,
#   'University of Bonn': 1,
#   'University of British Columbia': 1,
#   'University of California': 2,
#   'University of Chicago': 1,
#   'University of Edinburgh': 1,
#   'University of Hawaii': 1,
#   'University of Illinois': 1,
#   'University of Louisville': 1,
#   'University of Minnesota': 1,
#   'University of Missouri': 2,
#   'University of Natural Resources and Life Sciences': 2,
#   'University of New South Wales': 1,
#   'University of North Carolina': 2,
#   'University of Ottawa': 1,
#   'University of Pennsylvania': 1,
#   'University of Pittsburgh': 1,
#   'University of Reading': 1,
#   'University of Regensburg': 1,
#   'University of Strathclyde': 2,
#   'University of Technology Sydney': 1,
#   'University of Toronto': 2,
#   'University of Vienna': 1,
#   'University of Washington': 1,
#   'University of Zurich': 1,
#   'Université Aix-Marseille': 1,
#   'Univerzita Karlova': 1,
#   'Univerzita Komenského': 33,
#   'Univerzita Konštantína Filozofa': 1,
#   'Univerzita PJ Šafárika': 5,
#   'Univerzita Palackého v Olomouci': 3,
#   'Univerzita svätého Cyrila a Metoda v Trnave': 2,
#   'Vienna University of Technology': 1,
#   'Vysoká škola chemicko-technologická': 1,
#   'Zeppelin University': 1,
#   'Západočeská univerzita v Plzni': 1,
#   'Česká akadémia vied': 5,
#   'České vysoké učení technické v Prahe': 1,
#   'Žilinská univerzita': 1},
#  'countries': {'Austrália': 9,
#   'Dánsko': 1,
#   'Francúzsko': 1,
#   'Holandsko': 4,
#   'Kanada': 9,
#   'Katar': 2,
#   'Nemecko': 6,
#   'Rakúsko': 9,
#   'Ruská Federácia': 1,
#   'Saudská Arábia': 2,
#   'Slovensko': 93,
#   'Spojené Arabské Emiráty': 2,
#   'USA': 27,
#   'Veľká Británia': 7,
#   'Írsko': 1,
#   'Česko': 14,
#   'Španielsko': 1,
#   'Švajčiarsko': 4},
#  'hindex': [37,
#   32,
#   37,
#   31,
#   31,
#   32,
#   35,
#   30,
#   32,
#   31,
#   38,
#   53,
#   32,
#   34,
#   44,
#   40,
#   30,
#   38,
#   56,
#   33,
#   72,
#   42,
#   32,
#   42,
#   30,
#   54,
#   49,
#   33,
#   37,
#   40,
#   41,
#   32,
#   78,
#   30,
#   49,
#   65,
#   45,
#   43,
#   31,
#   34,
#   34,
#   69,
#   123,
#   45,
#   48,
#   32,
#   32,
#   40,
#   55,
#   42,
#   47,
#   42,
#   44,
#   33,
#   38,
#   86,
#   104,
#   32,
#   41,
#   67,
#   32,
#   41,
#   38,
#   89,
#   35,
#   30,
#   31,
#   60,
#   30,
#   34,
#   68,
#   44,
#   35,
#   47,
#   30,
#   32,
#   38,
#   41,
#   38,
#   44,
#   56,
#   46,
#   52,
#   32,
#   30,
#   44,
#   32,
#   35,
#   31,
#   45,
#   35,
#   41,
#   42,
#   61,
#   32,
#   79,
#   46,
#   42,
#   41,
#   36,
#   40,
#   37,
#   43,
#   34,
#   38,
#   31,
#   35,
#   32,
#   30,
#   38,
#   45,
#   38,
#   30,
#   55,
#   30,
#   32,
#   31,
#   47,
#   54,
#   38,
#   30,
#   33,
#   44,
#   55,
#   33,
#   45,
#   36,
#   32,
#   30,
#   31,
#   58,
#   33,
#   49,
#   41,
#   87,
#   44,
#   36,
#   47,
#   33,
#   33,
#   42,
#   37,
#   33,
#   42,
#   44,
#   30,
#   34,
#   38,
#   48,
#   32,
#   55,
#   48,
#   31,
#   35,
#   31,
#   37,
#   52,
#   37,
#   57,
#   30,
#   31,
#   59,
#   36,
#   52,
#   30,
#   33,
#   30,
#   30,
#   30,
#   32,
#   33,
#   31,
#   41,
#   34,
#   34,
#   30,
#   57,
#   35,
#   43,
#   30,
#   36,
#   34,
#   40,
#   57,
#   32,
#   33,
#   35,
#   40,
#   38,
#   37,
#   32,
#   41,
#   35],
#  'man': 4,
#  'women': 0}
